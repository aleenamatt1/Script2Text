# %%
# Student Number: C22716399
# Student Name: Aaron Baggot
# Transformation Task 1

# %%
import glob
print(glob.glob("data/samples/*"))
# Out:
# []

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from pathlib import Path

# %%
# Open the image war.png
img_path = Path("/Users/aaronbaggot/Desktop/Script2Text/data/samples/Handwritten_2025-09-18_110153_2.png")
# Open image in greyscale
I = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)

# %%
if I is None:
    raise exception(f"Image not found: {img_path}")

# %%
# View original image and histogram

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.imshow(I, cmap = "gray")
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
# .ravel() flattens the 2D image into a 1D array of pixel intensity values
# If the image is 512 × 512, then I.ravel() is a 1D array with 512 × 512 = 262,144 pixel values
plt.hist(I.ravel(),256,[0,256])
plt.title("Original Histogram")

plt.show()
# Out:
# /var/folders/nh/gg0k5rzx0cscygqdr507zl780000gn/T/ipykernel_41074/3741921589.py:11: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(I.ravel(),256,[0,256])

# %%
import glob
print(glob.glob("data/samples/*"))
import cv2
import numpy as np
from matplotlib import pyplot as plt
from pathlib import Path
# Out:
# []

# %%
# Histogram equalisation
equalized = cv2.equalizeHist(I)

# %%
# Equalised image and new histogram
plt.figure(figsize=(12,5)) # New figure window

plt.subplot(1,2,1) # Defines the layout as 1 row, 2 columns of plots.
plt.imshow(equalized, cmap="gray") # displays image stored in equalized and forces grayscale
plt.title("Equalised image")
plt.axis("off") # Removes x,y axis for cleaner image look

plt.subplot(1,2,2)
plt.hist(equalized.ravel(),256,[0,256]) # flattens equalized image into 1D array
plt.title("Equalised Histogram")

plt.show()
# Out:
# /var/folders/nh/gg0k5rzx0cscygqdr507zl780000gn/T/ipykernel_41074/211296866.py:10: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(equalized.ravel(),256,[0,256]) # flattens equalized image into 1D array

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 cv2.imwrite("../output/sample_image.png")
#
# error: OpenCV(4.12.0) :-1: error: (-5:Bad argument) in function 'imwrite'
# > Overload resolution failed:
# >  - imwrite() missing required argument 'img' (pos 2)
# >  - imwrite() missing required argument 'img' (pos 2)
